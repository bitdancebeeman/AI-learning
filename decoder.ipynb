# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import time
import os

# 定义神经网络模型
class OddEvenPredictor(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super(OddEvenPredictor, self).__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)
        self.network = nn.Sequential(
            nn.Linear(embedding_dim, 4),
            nn.ReLU(),
            nn.Linear(4, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        x = self.embedding(x.long())
        x = x.view(x.size(0), -1)  # 展平嵌入
        return self.network(x)

# 检查是否有CUDA，如果有则使用GPU，否则使用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 实例化模型并移动到GPU
model = OddEvenPredictor(100, 1).to(device)

# 定义损失函数和优化器
criterion = nn.BCELoss()  # 二元交叉熵损失
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 训练数据
X_train = torch.tensor([[i] for i in range(0, 100)], dtype=torch.long)
y_train = torch.tensor([[int(i % 2 == 0)] for i in range(0, 100)], dtype=torch.float)

# 创建Dataset和DataLoader
dataset = TensorDataset(X_train, y_train)
dataloader = DataLoader(dataset, batch_size=100, shuffle=True)

# 记录训练开始时间
start_time = time.time()

checkpoint_dir = '/mnt/workspace/odd_even_model'  # 定义checkpoint的保存目录

# 训练循环
epochs = 10000
for epoch in range(epochs):
    for batch_X, batch_y in dataloader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()   # 清空梯度
        outputs = model(batch_X)  # 前向传播
        loss = criterion(outputs, batch_y)  # 计算损失
        loss.backward()  # 反向传播
        optimizer.step()  # 更新权重

    if (epoch+1) % 100 == 0:
        # 打印训练损失和耗时
        end_time = time.time()
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Time Elapsed {end_time - start_time:.2f} seconds')
    if (epoch+1) % 1000 == 0:
        # 保存checkpoint
        checkpoint_path = f'{checkpoint_dir}/checkpoint_epoch_{epoch+1}.pth'
        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss.item(),
            'epoch': epoch + 1,
        }, checkpoint_path)
        print(f'Checkpoint saved at {checkpoint_path}')

# 记录训练结束时间
end_time = time.time()
# 计算训练耗时
elapsed_time = end_time - start_time
# 转换耗时为小时、分钟和秒
hours = int(elapsed_time // 3600)
minutes = int((elapsed_time % 3600) // 60)
seconds = int(elapsed_time % 60)
print(f'Training completed in {hours} hours, {minutes} minutes and {seconds} seconds')
# Out:
# Epoch [100/10000], Loss: 0.6876, Time Elapsed 0.22 seconds
# Epoch [200/10000], Loss: 0.6708, Time Elapsed 0.44 seconds
# Epoch [300/10000], Loss: 0.6383, Time Elapsed 0.66 seconds
# Epoch [400/10000], Loss: 0.5879, Time Elapsed 0.87 seconds
# Epoch [500/10000], Loss: 0.5134, Time Elapsed 1.09 seconds
# Epoch [600/10000], Loss: 0.4275, Time Elapsed 1.30 seconds
# Epoch [700/10000], Loss: 0.3460, Time Elapsed 1.52 seconds
# Epoch [800/10000], Loss: 0.2753, Time Elapsed 1.74 seconds
# Epoch [900/10000], Loss: 0.2231, Time Elapsed 1.95 seconds
# Epoch [1000/10000], Loss: 0.1866, Time Elapsed 2.17 seconds
# Checkpoint saved at /mnt/workspace/odd_even_model/checkpoint_epoch_1000.pth
# Epoch [1100/10000], Loss: 0.1611, Time Elapsed 2.38 seconds
# Epoch [1200/10000], Loss: 0.1431, Time Elapsed 2.60 seconds
# Epoch [1300/10000], Loss: 0.1300, Time Elapsed 2.81 seconds
# Epoch [8600/10000], Loss: 0.0015, Time Elapsed 18.55 seconds
# Epoch [8700/10000], Loss: 0.0014, Time Elapsed 18.77 seconds
# Epoch [8800/10000], Loss: 0.0014, Time Elapsed 18.98 seconds
# Epoch [8900/10000], Loss: 0.0013, Time Elapsed 19.20 seconds
# Epoch [9000/10000], Loss: 0.0013, Time Elapsed 19.41 seconds
# Checkpoint saved at /mnt/workspace/odd_even_model/checkpoint_epoch_9000.pth
# Epoch [9100/10000], Loss: 0.0012, Time Elapsed 19.63 seconds
# Epoch [9200/10000], Loss: 0.0011, Time Elapsed 19.85 seconds
# Epoch [9300/10000], Loss: 0.0011, Time Elapsed 20.06 seconds
# Epoch [9400/10000], Loss: 0.0011, Time Elapsed 20.28 seconds
# Epoch [9500/10000], Loss: 0.0010, Time Elapsed 20.50 seconds
# Epoch [9600/10000], Loss: 0.0010, Time Elapsed 20.71 seconds
# Epoch [9700/10000], Loss: 0.0009, Time Elapsed 20.93 seconds
# Epoch [9800/10000], Loss: 0.0009, Time Elapsed 21.14 seconds
# Epoch [9900/10000], Loss: 0.0008, Time Elapsed 21.36 seconds
# Epoch [10000/10000], Loss: 0.0008, Time Elapsed 21.57 seconds
# Checkpoint saved at /mnt/workspace/odd_even_model/checkpoint_epoch_10000.pth
# Training completed in 0 hours, 0 minutes and 21 seconds

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import time
import os

#os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
#os.environ['TORCH_USE_CUDA_DSA'] = "1"
# 定义神经网络模型
class OddEvenPredictor(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super(OddEvenPredictor, self).__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)
        self.network = nn.Sequential(
            nn.Linear(embedding_dim, 4),
            nn.ReLU(),
            nn.Linear(4, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        x = self.embedding(x.long())
        x = x.view(x.size(0), -1)  # 展平嵌入
        return self.network(x)

# 检查是否有CUDA，如果有则使用GPU，否则使用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 实例化模型并移动到GPU
model = OddEvenPredictor(100, 1).to(device)

# 加载模型的状态字典
# 请确保 checkpoint_path 指向正确的模型文件路径
checkpoint_path = '/mnt/workspace/odd_even_model/checkpoint_epoch_10000.pth'
checkpoint = torch.load(checkpoint_path, map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
# 打印模型的参数

for name, param in model.named_parameters():
    print(f"Parameter name: {name}")
    print(f"Parameter size: {param.size()}")
    print(f"Parameter values: {param}")
    print("\n")

# 将模型设置为评估模式
model.eval()

# 准备预测数据
# 这里我们创建一个包含多个测试数字的张量
test_numbers = torch.tensor([[i] for i in range(0, 100)], dtype=torch.long).to(device)

# 进行预测
with torch.no_grad():  # 预测时不计算梯度
    predictions = model(test_numbers)
    predictions = predictions.squeeze()  # 移除多余的维度，方便打印
    predicted_odd_even = ['奇数' if pred < 0.5 else '偶数' for pred in predictions]

# 打印预测结果
for number, odd_even in zip(test_numbers.tolist(), predicted_odd_even):
    print(f'The number {number[0]} is predicted as {odd_even}')
# Out:
# Parameter name: embedding.weight
# Parameter size: torch.Size([100, 1])
# Parameter values: Parameter containing:
# tensor([[ 2.2162],
#         [-0.3710],
#         [ 2.2167],
#         [-0.3710],
#         [-3.2940],
#         [-0.3710],
#         [-3.2781],
#         [-0.3710],
#         [-3.2711],
#         [-0.3710],
#         [-3.2602],
#         [-0.3711],
#         [-3.2759],
#         [-0.3710],
#         [-3.3754],
#         [-0.3710],
#         [ 2.2162],
#         [-0.3710],
#         [ 2.2168],
#         [-0.3710],
#         [-3.2406],
#         [-0.1724],
#         [ 2.2235],
#         [-0.3710],
#         [ 2.2163],
#         [-0.3710],
#         [ 2.2161],
#         [-0.3710],
#         [ 2.2161],
#         [-0.3710],
#         [ 2.2164],
#         [-0.3710],
#         [ 2.2178],
#         [-0.3710],
#         [-3.1229],
#         [-0.3710],
#         [ 2.2206],
#         [-0.3710],
#         [ 2.2157],
#         [-0.3710],
#         [ 2.2160],
#         [-0.3710],
#         [ 2.2162],
#         [-0.3710],
#         [ 2.2160],
#         [-0.3710],
#         [ 2.2164],
#         [-0.3710],
#         [-3.4113],
#         [-0.3710],
#         [-3.2193],
#         [-0.3710],
#         [ 2.2162],
#         [-0.3710],
#         [ 2.2164],
#         [-0.3710],
#         [ 2.2176],
#         [-0.3710],
#         [-3.1894],
#         [-0.3711],
#         [-3.2760],
#         [-0.3710],
#         [ 2.2159],
#         [-0.3711],
#         [ 2.2198],
#         [-0.3710],
#         [ 2.2159],
#         [-0.3710],
#         [ 2.2165],
#         [-0.3710],
#         [-3.2057],
#         [-0.3710],
#         [ 2.2175],
#         [ 0.1795],
#         [ 2.2161],
#         [-0.3710],
#         [ 2.2163],
#         [-0.3710],
#         [ 2.6329],
#         [-0.3710],
#         [ 2.2170],
#         [-0.3710],
#         [ 2.2165],
#         [-0.3711],
#         [-3.3528],
#         [-0.3710],
#         [-3.2711],
#         [-0.3710],
#         [-3.2806],
#         [-0.3710],
#         [ 2.2164],
#         [-0.3710],
#         [-3.2828],
#         [-0.3710],
#         [-3.2265],
#         [-0.3711],
#         [ 2.2169],
#         [-0.3710],
#         [-3.5533],
#         [-0.3710]], device='cuda:0', requires_grad=True)
#
#
# Parameter name: network.0.weight
# Parameter size: torch.Size([4, 1])
# Parameter values: Parameter containing:
# tensor([[-1.0365],
#         [-3.0169],
#         [-1.1771],
#         [-2.7179]], device='cuda:0', requires_grad=True)
#
#
# Parameter name: network.0.bias
# Parameter size: torch.Size([4])
# Parameter values: Parameter containing:
# tensor([ 2.2964, -1.1194,  2.6080, -1.0085], device='cuda:0',
#        requires_grad=True)
#
#
# Parameter name: network.2.weight
# Parameter size: torch.Size([1, 4])
# Parameter values: Parameter containing:
# tensor([[-2.7991,  2.3817, -3.1164,  2.5933]], device='cuda:0',
#        requires_grad=True)
#
#
# Parameter name: network.2.bias
# Parameter size: torch.Size([1])
# Parameter values: Parameter containing:
# tensor([5.9651], device='cuda:0', requires_grad=True)
#
#
# The number 0 is predicted as 偶数
# The number 1 is predicted as 奇数
# The number 2 is predicted as 偶数
# The number 3 is predicted as 奇数
# The number 4 is predicted as 偶数
# The number 5 is predicted as 奇数
# The number 6 is predicted as 偶数
# The number 7 is predicted as 奇数
# The number 8 is predicted as 偶数
# The number 9 is predicted as 奇数
# The number 10 is predicted as 偶数
# The number 11 is predicted as 奇数
# The number 12 is predicted as 偶数
# The number 13 is predicted as 奇数
# The number 14 is predicted as 偶数
# The number 15 is predicted as 奇数
# The number 16 is predicted as 偶数
# The number 17 is predicted as 奇数
# The number 18 is predicted as 偶数
# The number 19 is predicted as 奇数
# The number 20 is predicted as 偶数
# The number 21 is predicted as 奇数
# The number 22 is predicted as 偶数
# The number 23 is predicted as 奇数
# The number 24 is predicted as 偶数
# The number 25 is predicted as 奇数
# The number 26 is predicted as 偶数
# The number 27 is predicted as 奇数
# The number 28 is predicted as 偶数
# The number 29 is predicted as 奇数
# The number 30 is predicted as 偶数
# The number 31 is predicted as 奇数
# The number 32 is predicted as 偶数
# The number 33 is predicted as 奇数
# The number 34 is predicted as 偶数
# The number 35 is predicted as 奇数
# The number 36 is predicted as 偶数
# The number 37 is predicted as 奇数
# The number 38 is predicted as 偶数
# The number 39 is predicted as 奇数
# The number 40 is predicted as 偶数
# The number 41 is predicted as 奇数
# The number 42 is predicted as 偶数
# The number 43 is predicted as 奇数
# The number 44 is predicted as 偶数
# The number 45 is predicted as 奇数
# The number 46 is predicted as 偶数
# The number 47 is predicted as 奇数
# The number 48 is predicted as 偶数
# The number 49 is predicted as 奇数
# The number 50 is predicted as 偶数
# The number 51 is predicted as 奇数
# The number 52 is predicted as 偶数
# The number 53 is predicted as 奇数
# The number 54 is predicted as 偶数
# The number 55 is predicted as 奇数
# The number 56 is predicted as 偶数
# The number 57 is predicted as 奇数
# The number 58 is predicted as 偶数
# The number 59 is predicted as 奇数
# The number 60 is predicted as 偶数
# The number 61 is predicted as 奇数
# The number 62 is predicted as 偶数
# The number 63 is predicted as 奇数
# The number 64 is predicted as 偶数
# The number 65 is predicted as 奇数
# The number 66 is predicted as 偶数
# The number 67 is predicted as 奇数
# The number 68 is predicted as 偶数
# The number 69 is predicted as 奇数
# The number 70 is predicted as 偶数
# The number 71 is predicted as 奇数
# The number 72 is predicted as 偶数
# The number 73 is predicted as 奇数
# The number 74 is predicted as 偶数
# The number 75 is predicted as 奇数
# The number 76 is predicted as 偶数
# The number 77 is predicted as 奇数
# The number 78 is predicted as 偶数
# The number 79 is predicted as 奇数
# The number 80 is predicted as 偶数
# The number 81 is predicted as 奇数
# The number 82 is predicted as 偶数
# The number 83 is predicted as 奇数
# The number 84 is predicted as 偶数
# The number 85 is predicted as 奇数
# The number 86 is predicted as 偶数
# The number 87 is predicted as 奇数
# The number 88 is predicted as 偶数
# The number 89 is predicted as 奇数
# The number 90 is predicted as 偶数
# The number 91 is predicted as 奇数
# The number 92 is predicted as 偶数
# The number 93 is predicted as 奇数
# The number 94 is predicted as 偶数
# The number 95 is predicted as 奇数
# The number 96 is predicted as 偶数
# The number 97 is predicted as 奇数
# The number 98 is predicted as 偶数
# The number 99 is predicted as 奇数
